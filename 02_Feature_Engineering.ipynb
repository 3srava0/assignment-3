# %% [markdown]
# <a href="https://colab.research.google.com/github/3srava0/assignment-3/blob/main/02_Feature_Engineering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Day 2: Feature Engineering
# Real Estate Investment Advisor System

print("="*60)
print("FEATURE ENGINEERING - Real Estate Data")
print("="*60)

# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

print("\n✅ Libraries imported successfully!")
# Out:
# ============================================================
# FEATURE ENGINEERING - Real Estate Data
# ============================================================
# Mounted at /content/drive
#
# ✅ Libraries imported successfully!

# %%
# Step 1: Load the cleaned dataset from Google Drive
print("\n" + "="*60)
print("STEP 1: LOAD CLEANED DATASET")
print("="*60)

# Load the cleaned dataset
df = pd.read_csv('/content/drive/MyDrive/india_housing_prices_cleaned.csv')

print(f"\n✅ Dataset loaded successfully!")
print(f"Shape: {df.shape}")
print(f"\nColumns: {list(df.columns)}")
print(f"\nFirst few rows:")
df.head()
# Out:
# ============================================================
# STEP 1: LOAD CLEANED DATASET
# ============================================================
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2709629022.py in <cell line: 0>()
#       5
#       6 # Load the cleaned dataset
# ----> 7 df = pd.read_csv('/content/drive/MyDrive/india_housing_prices_cleaned.csv')
#       8
#       9 print(f"\n✅ Dataset loaded successfully!")
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/india_housing_prices_cleaned.csv'

# %%
# Check Google Drive contents
import os

print("Checking Google Drive contents...\n")
print("Root folder:")
# !ls -la /content/drive/MyDrive/

print("\n" + "="*60)
print("Searching for cleaned dataset...")
for root, dirs, files in os.walk('/content/drive/MyDrive'):
    for file in files:
        if 'cleaned' in file.lower() or 'housing' in file.lower():
            full_path = os.path.join(root, file)
            print(f"Found: {full_path}")
# Out:
# Checking Google Drive contents...
#
# Root folder:
# total 863020
# -r-------- 1 root root 19455226 Nov 11  2015  145953268-Solutions-to-IE-Irodov-s-Problems-in-General-Physics-Volume-I-Abhay-Kumar-Singh.pdf
# -rw------- 1 root root  3286078 Sep 25  2018  1537861773260726901609.jpg
# -rw------- 1 root root    32546 Apr  5  2021  1606143532742.jpg
# -rw------- 1 root root    36603 Apr  5  2021  1609228640903.jpg
# -rw------- 1 root root    40812 Apr  5  2021  1610798455956.jpg
# -rw------- 1 root root    26119 Apr  5  2021  1610798456060.jpg
# -rw------- 1 root root    18249 Apr  5  2021  1610798456422.jpg
# -rw------- 1 root root    43032 Apr  5  2021  1610798456514.jpg
# -rw------- 1 root root    38270 Apr  5  2021  1615094611717.jpg
# -rw------- 1 root root    21540 Apr  5  2021  1615557035466.jpg
# -rw------- 1 root root    17876 Apr  5  2021  1615557036256.jpg
# -rw------- 1 root root    21509 Apr  5  2021  1615875754016.jpg
# -rw------- 1 root root   208616 Apr  5  2021 '2021-03-12 (1).png'
# -rw------- 1 root root   654341 Mar 20  2017  A17126142176.pdf
# -rw------- 1 root root   253078 May 29  2022  A70405517008_Assginment3.pdf
# -rw------- 1 root root 32081606 Nov 26  2021  A70405517008_MnCJournal_Sem5.pdf
# -rw------- 1 root root   640765 May 16  2022  A70405517008_PhotographyASSG.pdf
# -rw------- 1 root root   228938 Aug  7  2020  Accountsdepartment_reply_for_outstanding.png.png
# -rw------- 1 root root  1149440 Dec 10  2017 'Agro Enviro Problems Module II.ppt'
# -rw------- 1 root root      172 Nov  5  2020 'AISSEE 2020 Class 9 Question Paper.gdoc'
# -rw------- 1 root root  1270272 Nov 15  2017  ALL_SYLLABUS_OF_B.doc
# -rw------- 1 root root   371407 Aug  7  2020  Amizone_recorded_till_sem3.png.png
# drwx------ 2 root root     4096 Jan  5  2022  ASET
# drwx------ 2 root root     4096 Jun 19  2021 'ASET (1)'
# drwx------ 2 root root     4096 Apr 30  2021 'ASET (2)'
# drwx------ 2 root root     4096 Apr 30  2021 'ASET (3)'
# drwx------ 2 root root     4096 Apr 30  2021 'ASET (4)'
# -rw------- 1 root root    12240 Oct  8  2017 'a shadow.docx'
# -rw------- 1 root root  3688252 May 26  2022 'Assignment 1_A70405517008.pdf'
# drwx------ 2 root root     4096 Jan 24 15:17  assignment-3
# -rw------- 1 root root        0 Sep 27  2022  AUD-20220927-WA0013.m4a
# -r-------- 1 root root   504503 Sep 13  2020  Audible_Catlog.csv
# -rw------- 1 root root     2490 Mar 19  2017  AutoReceipt-142054607.pdf
# drwx------ 2 root root     4096 Aug 23  2020  BankStatement
# drwx------ 2 root root     4096 Sep 28  2020  Books
# -rw------- 1 root root   100678 Apr 13  2020 'Business-- Enablers.pdf.pdf'
# -rw------- 1 root root      172 Aug 12  2020 'Business letter.gdoc'
# -rw------- 1 root root      172 Jul  4  2019  cellular_automaton.py.gdoc
# -rw------- 1 root root  3232812 Jan 15  2022 'Centrifugal Pump Impeller Modelling and Structural Analysis by PSVS Sai Sravan.pdf'
# drwx------ 2 root root     4096 May  5  2021  Certificate
# -rw------- 1 root root   476471 Oct  8  2017  ch-7.pdf
# drwx------ 2 root root     4096 Aug 14  2018  Classroom
# drwx------ 2 root root     4096 Jul  4  2019 'Colab Notebooks'
# drwx------ 2 root root     4096 Aug 25  2020  college
# -rw------- 1 root root  1284906 Aug  7  2020  College_Id.Back_part.png.jpg
# -rw------- 1 root root   948206 Aug  7  2020  College_Id.front_side.png.jpg
# -rw------- 1 root root      172 Jun 15  2019 'Consulting proposal.gslides'
# -rw------- 1 root root   163649 Dec  1  2017 'Document from Sai Sravan'
# -rw------- 1 root root   200602 Nov 24  2017 'Document from Sravan'
# -rw------- 1 root root    12513 Oct 27  2017 'Document from Sravan (1)'
# -rw------- 1 root root    32512 Oct 28  2017 'Document from Sravan (1).pdf'
# -rw------- 1 root root    13291 Oct 17  2017 'Document from Sravan (2)'
# -rw------- 1 root root   104508 Oct 16  2017 'Document from Sravan (3)'
# -rw------- 1 root root    72175 Oct 16  2017 'Document from Sravan (4)'
# -rw------- 1 root root  1326566 Oct 28  2017 'Document from Sravan.pdf'
# -rw------- 1 root root    45204 Oct  8  2017 'dream children.docx'
# -rw------- 1 root root   994136 Jun 18  2024  EAadhaar_0000009534013320240112151331_1806202423731.pdf
# drwx------ 2 root root     4096 Aug 31  2020 'Easeus 31 19_11'
# -rw------- 1 root root  4484226 Aug 21  2018 'Ecrivez les phrases au futur proche. (Make sentences using futur proche) (21 Aug 2018 4:45:21 pm).jpeg'
# -rw------- 1 root root  2215359 Aug 28  2016 'Electro Chemistry Booklet Solution Subjective.pdf'
# -rw------- 1 root root   432788 Oct 12  2017 'experiment no 2-2.pdf'
# -rw------- 1 root root   610122 Oct  3  2017 'experiment no 3-2.pdf'
# -rw------- 1 root root   262051 Feb 14  2018 'Expriment no -2.pdf'
# -rw------- 1 root root   516857 Feb 14  2018 'Expriment no -3.pdf'
# -rw------- 1 root root   514916 Feb 14  2018 'Expriment no -4.pdf'
# -rw------- 1 root root   403563 Feb 14  2018 'Expriment no -5 (1).pdf'
# -rw------- 1 root root   403563 Mar 11  2018 'Expriment no -5.pdf'
# -rw------- 1 root root   567708 Feb 14  2018 'Expriment no -6.pdf'
# -rw------- 1 root root   419725 Feb 14  2018 'Expriment no -7.pdf'
# -rw------- 1 root root    57673 Jul 30  2018  .facebook_1532931462319.jpg
# -rw------- 1 root root   763113 May 18  2022 "Father's Documents.rar"
# -rw------- 1 root root      172 Dec 27 13:43 'Garbage Classification Project Guide.gdoc'
# -rw------- 1 root root  3992312 Aug 23  2020 'History (2).pdf'
# -rw------- 1 root root  3776107 Aug  7  2020 'Hospital_Admit_bill(my father'\''s).png.jpg'
# -rw------- 1 root root  3017667 Jun  6  2014 'How to get started with Drive.pdf'
# -rw------- 1 root root  3863153 Aug 23  2020 'I am sharing '\''History (1)'\'' with you.pdf'
# -rw------- 1 root root 20048289 Mar 31  2025 "I am sharing 'WagonR-99011M69R12-74W' with you.pdf"
# -rw------- 1 root root  1608404 Apr 15  2021 'IC_AC_FEB 2021_MajProj_SaiSravanPSVS (1).pdf'
# -rw------- 1 root root  1608404 Apr 15  2021 'IC_AC_FEB 2021_MajProj_SaiSravanPSVS (2).pdf'
# -rw------- 1 root root  1608404 Apr 15  2021 'IC_AC_FEB 2021_MajProj_SaiSravanPSVS.pdf'
# -rw------- 1 root root  1127589 Feb 24  2016  IMG_20150411_195820.jpg
# -rw------- 1 root root   149468 Feb 24  2016  IMG_20150424_103309.jpg
# -rw------- 1 root root   681613 Feb 24  2016  IMG_20150517_120237.jpg
# -rw------- 1 root root   772643 Feb 24  2016  IMG_20150719_112125.jpg
# -rw------- 1 root root   428221 Feb 24  2016  IMG_20150826_214630243.jpg
# -rw------- 1 root root   156919 Oct 19  2015 'IMG_20151013_215900 (1).jpg'
# -rw------- 1 root root   156919 Oct 19  2015  IMG_20151013_215900.jpg
# -rw------- 1 root root   739585 Feb 24  2016  IMG_20151210_110736.jpg
# -rw------- 1 root root   780037 Feb 24  2016  IMG_20151226_121002.jpg
# -rw------- 1 root root   746237 Feb 24  2016  IMG_20151231_143136.jpg
# -rw------- 1 root root   766855 Feb 24  2016  IMG_20151231_143148.jpg
# -rw------- 1 root root   740189 Feb 24  2016  IMG_20151231_143222.jpg
# -rw------- 1 root root   687935 Feb 24  2016  IMG_20151231_143258.jpg
# -rw------- 1 root root   764103 Feb 24  2016  IMG_20160220_091955.jpg
# -rw------- 1 root root   394192 Feb 24  2016  IMG_20160220_093249.jpg
# -rw------- 1 root root   766383 Feb 24  2016  IMG_20160220_164555.jpg
# -rw------- 1 root root   738460 Feb 24  2016  IMG_20160220_164605.jpg
# -rw------- 1 root root   762477 Feb 24  2016  IMG_20160220_164614.jpg
# -rw------- 1 root root   746534 Feb 24  2016  IMG_20160220_164621.jpg
# -rw------- 1 root root   733085 Feb 24  2016  IMG_20160220_164637.jpg
# -rw------- 1 root root   745042 Feb 24  2016  IMG_20160220_164645.jpg
# -rw------- 1 root root   739558 Feb 24  2016  IMG_20160220_164654.jpg
# -rw------- 1 root root   822738 Aug 30  2016  IMG_20160817_082722.jpg
# -rw------- 1 root root   797301 Oct  8  2016 'IMG_20161008_151806 (1).jpg'
# -rw------- 1 root root   797301 Sep 22  2017  IMG_20161008_151806.jpg
# -rw------- 1 root root   706855 Oct  8  2016 'IMG_20161008_151812 (1).jpg'
# -rw------- 1 root root   706855 Sep 22  2017  IMG_20161008_151812.jpg
# -rw------- 1 root root   772412 Oct  8  2016 'IMG_20161008_151822 (1).jpg'
# -rw------- 1 root root   772412 Sep 22  2017  IMG_20161008_151822.jpg
# -rw------- 1 root root   719684 Oct  8  2016 'IMG_20161008_151826 (1).jpg'
# -rw------- 1 root root   719684 Sep 22  2017  IMG_20161008_151826.jpg
# -rw------- 1 root root   723727 Oct  8  2016 'IMG_20161008_151834 (1).jpg'
# -rw------- 1 root root   723727 Sep 22  2017  IMG_20161008_151834.jpg
# -rw------- 1 root root   722914 Oct  8  2016 'IMG_20161008_151838 (1).jpg'
# -rw------- 1 root root   722914 Sep 22  2017  IMG_20161008_151838.jpg
# -rw------- 1 root root   774082 Oct  8  2016 'IMG_20161008_151847 (1).jpg'
# -rw------- 1 root root   774082 Sep 22  2017  IMG_20161008_151847.jpg
# -rw------- 1 root root   722606 Oct  8  2016 'IMG_20161008_151855 (1).jpg'
# -rw------- 1 root root   722606 Sep 22  2017  IMG_20161008_151855.jpg
# -rw------- 1 root root   727216 Oct  8  2016 'IMG_20161008_165145 (1).jpg'
# -rw------- 1 root root   727216 Sep 22  2017  IMG_20161008_165145.jpg
# -rw------- 1 root root   695064 Oct  8  2016 'IMG_20161008_165152 (1).jpg'
# -rw------- 1 root root   695064 Sep 22  2017  IMG_20161008_165152.jpg
# -rw------- 1 root root   742203 Oct  8  2016 'IMG_20161008_165159 (1).jpg'
# -rw------- 1 root root   742203 Sep 22  2017  IMG_20161008_165159.jpg
# -rw------- 1 root root   744731 Oct  8  2016 'IMG_20161008_165206 (1).jpg'
# -rw------- 1 root root   744731 Sep 22  2017  IMG_20161008_165206.jpg
# -rw------- 1 root root   762935 Oct  8  2016 'IMG_20161008_165212 (1).jpg'
# -rw------- 1 root root   762935 Sep 22  2017  IMG_20161008_165212.jpg
# -rw------- 1 root root   810052 Oct  8  2016 'IMG_20161008_165222 (1).jpg'
# -rw------- 1 root root   810052 Sep 22  2017  IMG_20161008_165222.jpg
# -rw------- 1 root root   898283 Oct  8  2016 'IMG_20161008_165308 (1).jpg'
# -rw------- 1 root root   898283 Sep 22  2017  IMG_20161008_165308.jpg
# -rw------- 1 root root   742459 Oct  8  2016 'IMG_20161008_165316 (1).jpg'
# -rw------- 1 root root   742459 Sep 22  2017  IMG_20161008_165316.jpg
# -rw------- 1 root root   732957 Oct  8  2016 'IMG_20161008_165408 (1).jpg'
# -rw------- 1 root root   732957 Sep 22  2017  IMG_20161008_165408.jpg
# -rw------- 1 root root   737496 Oct  8  2016 'IMG_20161008_165436 (1).jpg'
# -rw------- 1 root root   737496 Sep 22  2017  IMG_20161008_165436.jpg
# -rw------- 1 root root   750281 Oct  8  2016 'IMG_20161008_165444 (1).jpg'
# -rw------- 1 root root   750281 Sep 22  2017  IMG_20161008_165444.jpg
# -rw------- 1 root root   734428 Oct  8  2016 'IMG_20161008_165451 (1).jpg'
# -rw------- 1 root root   734428 Sep 22  2017  IMG_20161008_165451.jpg
# -rw------- 1 root root   698025 Sep 22  2017  IMG_20161020_174902.jpg
# -rw------- 1 root root   759985 Sep 22  2017  IMG_20161020_174914.jpg
# -rw------- 1 root root   784520 Sep 22  2017  IMG_20161020_174919.jpg
# -rw------- 1 root root   746137 Sep 22  2017  IMG_20161020_174934.jpg
# -rw------- 1 root root   712443 Sep 22  2017  IMG_20161020_174939.jpg
# -rw------- 1 root root  1662093 Aug 18  2017  IMG_20170424_050547.jpg
# -rw------- 1 root root  2133087 Aug 18  2017  IMG_20170429_195503.jpg
# -rw------- 1 root root  2141181 Aug 18  2017  IMG_20170429_195715.jpg
# -rw------- 1 root root  3058660 Aug 18  2017  IMG_20170430_115459.jpg
# -rw------- 1 root root  3044338 Aug 18  2017  IMG_20170430_115527.jpg
# -rw------- 1 root root  3446312 Aug 18  2017  IMG_20170430_115645.jpg
# -rw------- 1 root root  3384502 Aug 18  2017  IMG_20170430_115648.jpg
# -rw------- 1 root root  3227207 Aug 18  2017  IMG_20170430_115749.jpg
# -rw------- 1 root root  2671914 Aug 18  2017  IMG_20170430_115849.jpg
# -rw------- 1 root root  2866928 Aug 18  2017  IMG_20170430_115904.jpg
# -rw------- 1 root root  2525002 Aug 18  2017  IMG_20170430_120054.jpg
# -rw------- 1 root root  2331050 Aug 18  2017  IMG_20170430_120059.jpg
# -rw------- 1 root root  2510578 Aug 18  2017  IMG_20170501_163239.jpg
# -rw------- 1 root root  2470769 Aug 18  2017  IMG_20170503_182722.jpg
# -rw------- 1 root root  1949007 Aug 18  2017  IMG_20170520_165737.jpg
# -rw------- 1 root root  3268679 Aug 18  2017  IMG_20170524_172322.jpg
# -rw------- 1 root root  3856476 Aug 18  2017  IMG_20170524_172337.jpg
# -rw------- 1 root root   121048 Aug  9  2017  IMG-20170805-WA0001.jpg
# -rw------- 1 root root   139422 Aug  9  2017  IMG-20170805-WA0002.jpg
# -rw------- 1 root root   170823 Aug  9  2017  IMG-20170805-WA0003.jpg
# -rw------- 1 root root   108344 Aug  9  2017  IMG-20170807-WA0005.jpg
# -rw------- 1 root root   207427 Aug  9  2017  IMG-20170807-WA0006.jpg
# -rw------- 1 root root    86868 Aug  9  2017  IMG-20170808-WA0000.jpg
# -rw------- 1 root root    88038 Aug  9  2017  IMG-20170808-WA0001.jpg
# -rw------- 1 root root   153409 Aug  9  2017  IMG-20170808-WA0002.jpg
# -rw------- 1 root root    86868 Aug  9  2017 'IMG-20170808-WA0005 (1).jpg'
# -rw------- 1 root root    86868 Aug  9  2017  IMG-20170808-WA0005.jpg
# -rw------- 1 root root   108887 Aug  9  2017  IMG-20170809-WA0000.jpg
# -rw------- 1 root root   141323 Aug  9  2017  IMG-20170809-WA0003.jpg
# -rw------- 1 root root   124499 Aug  9  2017  IMG-20170809-WA0005.jpg
# -rw------- 1 root root    75710 Aug  9  2017  IMG-20170809-WA0006.jpg
# -rw------- 1 root root   124020 Sep  6  2017  IMG-20170823-WA0003.jpg
# -rw------- 1 root root    98796 Sep  6  2017  IMG-20170824-WA0005.jpg
# -rw------- 1 root root    84034 Sep  6  2017  IMG-20170824-WA0006.jpg
# -rw------- 1 root root    72272 Sep  6  2017  IMG-20170824-WA0007.jpg
# -rw------- 1 root root   319215 Sep  6  2017  IMG-20170825-WA0011.jpg
# -rw------- 1 root root    41676 Sep  6  2017  IMG-20170828-WA0045.jpg
# -rw------- 1 root root   129051 Sep  6  2017  IMG-20170828-WA0046.jpg
# -rw------- 1 root root    59940 Sep  1  2017  IMG-20170831-WA0002.jpg
# -rw------- 1 root root    56215 Sep  1  2017  IMG-20170831-WA0003.jpg
# -rw------- 1 root root    48641 Sep  1  2017  IMG-20170831-WA0004.jpg
# -rw------- 1 root root    53463 Sep  1  2017  IMG-20170831-WA0005.jpg
# -rw------- 1 root root    49919 Sep  1  2017  IMG-20170831-WA0006.jpg
# -rw------- 1 root root    58118 Sep  1  2017  IMG-20170831-WA0007.jpg
# -rw------- 1 root root    88297 Sep  6  2017  IMG-20170901-WA0006.jpg
# -rw------- 1 root root    71723 Sep  6  2017  IMG-20170901-WA0007.jpg
# -rw------- 1 root root    13953 Sep  6  2017  IMG-20170905-WA0006.jpg
# -rw------- 1 root root    30508 Sep  6  2017  IMG-20170905-WA0007.jpg
# -rw------- 1 root root    76656 Sep  6  2017  IMG-20170905-WA0009.jpg
# -rw------- 1 root root   119047 Sep  6  2017  IMG-20170905-WA0010.jpg
# -rw------- 1 root root   258637 Sep  6  2017  IMG-20170905-WA0013.jpg
# -rw------- 1 root root   133085 Oct  1  2017 'IMG-20170929-WA0012 (1).jpg'
# -rw------- 1 root root   133085 Oct  2  2017  IMG-20170929-WA0012.jpg
# -rw------- 1 root root   126619 Oct  1  2017 'IMG-20170929-WA0013 (1).jpg'
# -rw------- 1 root root   126619 Oct  2  2017  IMG-20170929-WA0013.jpg
# -rw------- 1 root root   148607 Oct  1  2017 'IMG-20170929-WA0014 (1).jpg'
# -rw------- 1 root root   148607 Oct  2  2017  IMG-20170929-WA0014.jpg
# -rw------- 1 root root   141821 Oct  1  2017 'IMG-20170930-WA0001 (1).jpg'
# -rw------- 1 root root   141821 Oct  2  2017  IMG-20170930-WA0001.jpg
# -rw------- 1 root root   125724 Oct  1  2017 'IMG-20170930-WA0002 (1).jpg'
# -rw------- 1 root root   125724 Oct  2  2017  IMG-20170930-WA0002.jpg
# -rw------- 1 root root    97803 Oct  1  2017 'IMG-20170930-WA0003 (1).jpg'
# -rw------- 1 root root    97803 Oct  2  2017  IMG-20170930-WA0003.jpg
# -rw------- 1 root root   150232 Oct  2  2017 'IMG-20170930-WA0004 (1).jpg'
# -rw------- 1 root root   150232 Oct  1  2017 'IMG-20170930-WA0004 (2).jpg'
# -rw------- 1 root root   150232 Oct  2  2017  IMG-20170930-WA0004.jpg
# -rw------- 1 root root   112548 Oct  2  2017 'IMG-20170930-WA0005 (1).jpg'
# -rw------- 1 root root   112548 Oct  1  2017 'IMG-20170930-WA0005 (2).jpg'
# -rw------- 1 root root   112548 Oct  2  2017  IMG-20170930-WA0005.jpg
# -rw------- 1 root root   142266 Oct  1  2017 'IMG-20170930-WA0006 (1).jpg'
# -rw------- 1 root root   142266 Oct  2  2017  IMG-20170930-WA0006.jpg
# -rw------- 1 root root   101013 Oct  1  2017 'IMG-20170930-WA0007 (1).jpg'
# -rw------- 1 root root   101013 Oct  2  2017  IMG-20170930-WA0007.jpg
# -rw------- 1 root root   111481 Oct  2  2017 'IMG-20170930-WA0008 (1).jpg'
# -rw------- 1 root root   111481 Oct  1  2017 'IMG-20170930-WA0008 (2).jpg'
# -rw------- 1 root root   111481 Oct  2  2017  IMG-20170930-WA0008.jpg
# -rw------- 1 root root   116963 Oct  1  2017 'IMG-20170930-WA0009 (1).jpg'
# -rw------- 1 root root   116963 Oct  2  2017  IMG-20170930-WA0009.jpg
# -rw------- 1 root root   105642 Oct  2  2017 'IMG-20170930-WA0010 (1).jpg'
# -rw------- 1 root root   105642 Oct  1  2017 'IMG-20170930-WA0010 (2).jpg'
# -rw------- 1 root root   105642 Oct  2  2017  IMG-20170930-WA0010.jpg
# -rw------- 1 root root    90032 Oct  1  2017 'IMG-20170930-WA0011 (1).jpg'
# -rw------- 1 root root    90032 Oct  2  2017  IMG-20170930-WA0011.jpg
# -rw------- 1 root root   105953 Oct  2  2017 'IMG-20170930-WA0012 (1).jpg'
# -rw------- 1 root root   105953 Oct  1  2017 'IMG-20170930-WA0012 (2).jpg'
# -rw------- 1 root root   105953 Oct  2  2017  IMG-20170930-WA0012.jpg
# -rw------- 1 root root   121070 Oct  1  2017 'IMG-20170930-WA0013 (1).jpg'
# -rw------- 1 root root   121070 Oct  2  2017  IMG-20170930-WA0013.jpg
# -rw------- 1 root root    84850 Oct  2  2017 'IMG-20170930-WA0014 (1).jpg'
# -rw------- 1 root root    84850 Oct  1  2017 'IMG-20170930-WA0014 (2).jpg'
# -rw------- 1 root root    84850 Oct  2  2017  IMG-20170930-WA0014.jpg
# -rw------- 1 root root   103635 Oct  2  2017 'IMG-20170930-WA0015 (1).jpg'
# -rw------- 1 root root   103635 Oct  1  2017 'IMG-20170930-WA0015 (2).jpg'
# -rw------- 1 root root   103635 Oct  2  2017  IMG-20170930-WA0015.jpg
# -rw------- 1 root root    58713 Oct  3  2017  IMG-20171003-WA0011.jpg
# -rw------- 1 root root    56415 Oct  3  2017  IMG-20171003-WA0012.jpg
# -rw------- 1 root root    56098 Oct  3  2017  IMG-20171003-WA0013.jpg
# -rw------- 1 root root    55513 Oct  3  2017  IMG-20171003-WA0014.jpg
# -rw------- 1 root root   136571 Oct  3  2017  IMG-20171003-WA0015.jpg
# -rw------- 1 root root   129277 Oct 19  2017  IMG-20171019-WA0014.jpg
# -rw------- 1 root root   108412 Oct 19  2017  IMG-20171019-WA0016.jpg
# -rw------- 1 root root   116250 Oct 19  2017  IMG-20171019-WA0018.jpg
# -rw------- 1 root root   104948 Oct 19  2017  IMG-20171019-WA0020.jpg
# -rw------- 1 root root   131346 Oct 19  2017  IMG-20171019-WA0022.jpg
# -rw------- 1 root root   109620 Oct 19  2017  IMG-20171019-WA0024.jpg
# -rw------- 1 root root   117158 Oct 19  2017  IMG-20171019-WA0026.jpg
# -rw------- 1 root root   138970 Oct 19  2017  IMG-20171019-WA0028.jpg
# -rw------- 1 root root    92016 Oct 19  2017  IMG-20171019-WA0029.jpg
# -rw------- 1 root root    61801 Nov  6  2017  IMG-20171105-WA0000.jpg
# -rw------- 1 root root    52596 Nov  6  2017  IMG-20171105-WA0001.jpg
# -rw------- 1 root root   268577 Nov  6  2017  IMG-20171105-WA0002.jpg
# -rw------- 1 root root    40362 Nov  6  2017  IMG-20171105-WA0003.jpg
# -rw------- 1 root root   128276 Nov  6  2017  IMG-20171105-WA0004.jpg
# -rw------- 1 root root    77473 Apr  5  2021  IMG-20200706-WA0000.jpg
# -rw------- 1 root root    74498 Apr  5  2021  IMG-20200711-WA0004.jpg
# -rw------- 1 root root    72749 Apr  5  2021  IMG-20200804-WA0004_1596678116020.jpg
# -rw------- 1 root root  3258333 Apr  5  2021  IMG_20201023_131916.jpg
# -rw------- 1 root root  3141323 Apr  5  2021  IMG_20201023_131926.jpg
# -rw------- 1 root root   269982 Apr  5  2021  IMG_20201026_165830.jpg
# -rw------- 1 root root  4279102 Nov 26  2021  IMG_20201110_203249.jpg
# -rw------- 1 root root  4208345 Nov 26  2021  IMG_20201110_203313.jpg
# -rw------- 1 root root  5862201 Nov 26  2021  IMG_20201117_123630.jpg
# -rw------- 1 root root  6488193 Nov 26  2021  IMG_20201117_123723.jpg
# -rw------- 1 root root  1910272 Nov 26  2021  IMG_20201117_124908.jpg
# -rw------- 1 root root  2049026 Nov 26  2021  IMG_20201117_124916.jpg
# -rw------- 1 root root  1097462 Nov 26  2021  IMG_20201117_125358.jpg
# -rw------- 1 root root  1157820 Nov 26  2021  IMG_20201117_125705.jpg
# -rw------- 1 root root  1194212 Nov 26  2021  IMG_20201117_125756.jpg
# -rw------- 1 root root  1312866 Nov 26  2021  IMG_20201117_125854.jpg
# -rw------- 1 root root  1694538 Nov 26  2021  IMG_20201117_131503.jpg
# -rw------- 1 root root  1297141 Nov 26  2021  IMG_20201117_133302.jpg
# -rw------- 1 root root  1196057 Nov 26  2021  IMG_20201117_133606.jpg
# -rw------- 1 root root  4525124 Nov 26  2021  IMG_20201206_190711.jpg
# -rw------- 1 root root    55163 Apr  5  2021  IMG-20201208-WA0008.jpg
# -rw------- 1 root root    39769 Apr  5  2021  IMG-20201208-WA0009.jpg
# -rw------- 1 root root    57328 Apr  5  2021  IMG-20201208-WA0012.jpg
# -rw------- 1 root root    65881 Apr  5  2021  IMG-20201208-WA0013.jpg
# -rw------- 1 root root  3111114 Apr  5  2021  IMG_20201212_104025.jpg
# -rw------- 1 root root  2901203 Apr  5  2021  IMG_20201212_104037.jpg
# -rw------- 1 root root    93522 Apr  5  2021  IMG-20201212-WA0007.jpg
# -rw------- 1 root root    86315 Apr  5  2021  IMG-20201216-WA0016.jpg
# -rw------- 1 root root    57999 Apr  5  2021  IMG-20201216-WA0020.jpg
# -rw------- 1 root root  1502500 Apr  5  2021  IMG_20201217_180936.jpg
# -rw------- 1 root root   119848 Apr  5  2021  IMG-20201217-WA0055.jpg
# -rw------- 1 root root   103885 Apr  5  2021  IMG-20201218-WA0007.jpg
# -rw------- 1 root root    96941 Apr  5  2021  IMG-20201218-WA0008.jpg
# -rw------- 1 root root    72772 Apr  5  2021  IMG-20201218-WA0009.jpg
# -rw------- 1 root root    63467 Apr  5  2021  IMG-20201218-WA0010.jpg
# -rw------- 1 root root    74977 Apr  5  2021  IMG-20201218-WA0011.jpg
# -rw------- 1 root root    51697 Apr  5  2021  IMG-20201218-WA0012.jpg
# -rw------- 1 root root    56474 Apr  5  2021  IMG-20201218-WA0013.jpg
# -rw------- 1 root root   100927 Apr  5  2021  IMG-20201218-WA0014.jpg
# -rw------- 1 root root    77027 Apr  5  2021  IMG-20201218-WA0015.jpg
# -rw------- 1 root root   147343 Apr  5  2021  IMG-20201218-WA0017.jpg
# -rw------- 1 root root    59760 Apr  5  2021  IMG-20201219-WA0000.jpg
# -rw------- 1 root root    26797 Apr  5  2021  IMG-20201219-WA0006.jpg
# -rw------- 1 root root  4110149 Apr  5  2021  IMG_20201223_120254.jpg
# -rw------- 1 root root    75873 Apr  5  2021  IMG-20201229-WA0001.jpg
# -rw------- 1 root root   164263 Apr  5  2021  IMG-20201231-WA0002.jpg
# -rw------- 1 root root    73980 Apr  5  2021  IMG-20201231-WA0004.jpg
# -rw------- 1 root root  3579776 Nov 26  2021  IMG_20210101_124112.jpg
# -rw------- 1 root root  3963994 Nov 26  2021  IMG_20210101_125148.jpg
# -rw------- 1 root root  4288144 Nov 26  2021  IMG_20210101_125336.jpg
# -rw------- 1 root root  4360136 Nov 26  2021  IMG_20210101_125408.jpg
# -rw------- 1 root root  4332426 Nov 26  2021  IMG_20210101_125552.jpg
# -rw------- 1 root root  4123128 Nov 26  2021  IMG_20210101_125625.jpg
# -rw------- 1 root root  4127801 Nov 26  2021  IMG_20210101_125631.jpg
# -rw------- 1 root root  4395365 Nov 26  2021  IMG_20210101_125650.jpg
# -rw------- 1 root root  2609721 Nov 26  2021  IMG_20210101_125733.jpg
# -rw------- 1 root root  4324783 Nov 26  2021  IMG_20210101_130016.jpg
# -rw------- 1 root root    87290 Apr  5  2021  IMG-20210101-WA0012.jpg
# -rw------- 1 root root    62353 Apr  5  2021  IMG-20210102-WA0002.jpg
# -rw------- 1 root root    63514 Apr  5  2021  IMG-20210103-WA0007.jpg
# -rw------- 1 root root    47482 Apr  5  2021  IMG-20210103-WA0008.jpg
# -rw------- 1 root root  4154374 Apr  5  2021  IMG_20210108_114420.jpg
# -rw------- 1 root root   212568 Apr  5  2021  IMG_20210108_114511.jpg
# -rw------- 1 root root   159289 Apr  5  2021  IMG-20210112-WA0005.jpg
# -rw------- 1 root root    38914 Apr  5  2021  IMG-20210113-WA0001.jpg
# -rw------- 1 root root   112453 Apr  5  2021  IMG-20210114-WA0012.jpg
# -rw------- 1 root root   225631 Apr  5  2021  IMG-20210114-WA0013.jpg
# -rw------- 1 root root    87763 Apr  5  2021  IMG-20210115-WA0003.jpg
# -rw------- 1 root root    94312 Apr  5  2021  IMG-20210116-WA0007.jpg
# -rw------- 1 root root   136734 Apr  5  2021  IMG-20210116-WA0008.jpg
# -rw------- 1 root root    78953 Apr  5  2021  IMG-20210119-WA0015.jpg
# -rw------- 1 root root    77154 Apr  5  2021  IMG-20210119-WA0016.jpg
# -rw------- 1 root root    88392 Apr  5  2021  IMG-20210119-WA0017.jpg
# -rw------- 1 root root    91282 Apr  5  2021  IMG-20210119-WA0018.jpg
# -rw------- 1 root root    85146 Apr  5  2021  IMG-20210119-WA0019.jpg
# -rw------- 1 root root   134710 Apr  5  2021  IMG-20210119-WA0022.jpg
# -rw------- 1 root root    47862 Apr  5  2021  IMG-20210119-WA0024.jpg
# -rw------- 1 root root  3629822 Apr  5  2021  IMG_20210120_104135.jpg
# -rw------- 1 root root  3608250 Apr  5  2021  IMG_20210120_104144.jpg
# -rw------- 1 root root  2795005 Nov 26  2021  IMG_20210209_173217.jpg
# -rw------- 1 root root    65857 Apr  5  2021  IMG-20210224-WA0015.jpg
# -rw------- 1 root root  3747618 Nov 26  2021  IMG_20210225_095300.jpg
# -rw------- 1 root root   525135 Nov 26  2021  IMG_20210225_095703.jpg
# -rw------- 1 root root  4043991 Nov 26  2021  IMG_20210225_104413.jpg
# -rw------- 1 root root  4212005 Nov 26  2021  IMG_20210225_104424.jpg
# -rw------- 1 root root  4221819 Nov 26  2021  IMG_20210225_104427.jpg
# -rw------- 1 root root  3877693 Nov 26  2021  IMG_20210228_084810.jpg
# -rw------- 1 root root  4127389 Nov 26  2021  IMG_20210228_084819.jpg
# -rw------- 1 root root    50419 Apr  5  2021  IMG-20210305-WA0002.jpg
# -rw------- 1 root root    56015 Apr  5  2021  IMG-20210305-WA0003.jpg
# -rw------- 1 root root    58179 Apr  5  2021  IMG-20210305-WA0004.jpg
# -rw------- 1 root root    58395 Apr  5  2021  IMG-20210305-WA0005.jpg
# -rw------- 1 root root    57183 Apr  5  2021  IMG-20210305-WA0006.jpg
# -rw------- 1 root root    53760 Apr  5  2021  IMG-20210305-WA0007.jpg
# -rw------- 1 root root    59463 Apr  5  2021  IMG-20210305-WA0008.jpg
# -rw------- 1 root root    54956 Apr  5  2021  IMG-20210305-WA0010.jpg
# -rw------- 1 root root    55544 Apr  5  2021  IMG-20210305-WA0011.jpg
# -rw------- 1 root root  4138831 Nov 26  2021  IMG_20210307_095759.jpg
# -rw------- 1 root root    80010 Apr  5  2021  IMG-20210307-WA0000.jpg
# -rw------- 1 root root    66829 Apr  5  2021  IMG-20210308-WA0001.jpg
# -rw------- 1 root root    76213 Apr  5  2021  IMG-20210308-WA0002.jpg
# -rw------- 1 root root   195876 Apr  5  2021  IMG-20210308-WA0003.jpg
# -rw------- 1 root root    97975 Apr  5  2021  IMG-20210308-WA0004.jpg
# -rw------- 1 root root    69771 Apr  5  2021  IMG-20210308-WA0008.jpg
# -rw------- 1 root root    65668 Apr  5  2021  IMG-20210308-WA0010.jpg
# -rw------- 1 root root    35209 Apr  5  2021  IMG-20210308-WA0011.jpg
# -rw------- 1 root root    82076 Apr  5  2021  IMG-20210310-WA0014.jpg
# -rw------- 1 root root    76439 Apr  5  2021  IMG-20210310-WA0018.jpg
# -rw------- 1 root root    87154 Apr  5  2021  IMG-20210310-WA0028.jpg
# -rw------- 1 root root    71329 Apr  5  2021  IMG-20210310-WA0029.jpg
# -rw------- 1 root root    89413 Apr  5  2021  IMG-20210310-WA0030.jpg
# -rw------- 1 root root    93361 Apr  5  2021  IMG-20210310-WA0031.jpg
# -rw------- 1 root root   105354 Apr  5  2021  IMG-20210310-WA0032.jpg
# -rw------- 1 root root    93337 Apr  5  2021  IMG-20210310-WA0033.jpg
# -rw------- 1 root root    72023 Apr  5  2021  IMG-20210310-WA0034.jpg
# -rw------- 1 root root    86924 Apr  5  2021  IMG-20210310-WA0035.jpg
# -rw------- 1 root root    70638 Apr  5  2021  IMG-20210310-WA0036.jpg
# -rw------- 1 root root   107753 Apr  5  2021  IMG-20210310-WA0037.jpg
# -rw------- 1 root root    74281 Apr  5  2021  IMG-20210310-WA0038.jpg
# -rw------- 1 root root    69424 Apr  5  2021  IMG-20210310-WA0039.jpg
# -rw------- 1 root root    81169 Apr  5  2021  IMG-20210310-WA0040.jpg
# -rw------- 1 root root    73757 Apr  5  2021  IMG-20210310-WA0041.jpg
# -rw------- 1 root root    87255 Apr  5  2021  IMG-20210310-WA0042.jpg
# -rw------- 1 root root    69971 Apr  5  2021  IMG-20210310-WA0043.jpg
# -rw------- 1 root root    62024 Apr  5  2021  IMG-20210310-WA0045.jpg
# -rw------- 1 root root    74114 Apr  5  2021  IMG-20210310-WA0046.jpg
# -rw------- 1 root root    79423 Apr  5  2021  IMG-20210310-WA0047.jpg
# -rw------- 1 root root   106387 Apr  5  2021  IMG-20210310-WA0048.jpg
# -rw------- 1 root root   124580 Apr  5  2021  IMG-20210310-WA0049.jpg
# -rw------- 1 root root   112843 Apr  5  2021  IMG-20210310-WA0050.jpg
# -rw------- 1 root root    93392 Apr  5  2021  IMG-20210310-WA0051.jpg
# -rw------- 1 root root   114796 Apr  5  2021  IMG-20210310-WA0054.jpg
# -rw------- 1 root root    84140 Apr  5  2021  IMG-20210310-WA0055.jpg
# -rw------- 1 root root    95412 Apr  5  2021  IMG-20210310-WA0056.jpg
# -rw------- 1 root root   104523 Apr  5  2021  IMG-20210310-WA0057.jpg
# -rw------- 1 root root   111899 Apr  5  2021  IMG-20210310-WA0058.jpg
# -rw------- 1 root root   112849 Apr  5  2021  IMG-20210310-WA0059.jpg
# -rw------- 1 root root   101983 Apr  5  2021  IMG-20210310-WA0060.jpg
# -rw------- 1 root root   123066 Apr  5  2021  IMG-20210310-WA0066.jpg
# -rw------- 1 root root    78635 Apr  5  2021  IMG-20210310-WA0067.jpg
# -rw------- 1 root root    36598 Apr  5  2021  IMG-20210311-WA0001.jpg
# -rw------- 1 root root    75622 Apr  5  2021  IMG-20210312-WA0000.jpg
# -rw------- 1 root root    76182 Apr  5  2021  IMG-20210312-WA0001.jpg
# -rw------- 1 root root   210531 Apr  5  2021  IMG-20210312-WA0004.jpg
# -rw------- 1 root root   169415 Apr  5  2021  IMG-20210312-WA0005.jpg
# -rw------- 1 root root   160802 Apr  5  2021  IMG-20210312-WA0006.jpg
# -rw------- 1 root root    29174 Apr  5  2021  IMG-20210313-WA0003.jpg
# -rw------- 1 root root   701854 Nov 26  2021  IMG_20210314_131720.jpg
# -rw------- 1 root root    50131 Apr  5  2021  IMG-20210314-WA0000.jpg
# -rw------- 1 root root    43092 Apr  5  2021  IMG-20210314-WA0001.jpg
# -rw------- 1 root root   106977 Apr  5  2021  IMG-20210315-WA0002.jpg
# -rw------- 1 root root    36898 Nov 26  2021  IMG_20210317_113531.jpg
# -rw------- 1 root root    69195 Apr  5  2021  IMG-20210317-WA0003.jpg
# -rw------- 1 root root    97022 Apr  5  2021  IMG-20210317-WA0006.jpg
# -rw------- 1 root root    33507 Apr  5  2021  IMG-20210320-WA0004.jpg
# -rw------- 1 root root  2518209 Nov 26  2021  IMG_20210321_082931.jpg
# -rw------- 1 root root   136651 Apr  5  2021  IMG-20210323-WA0000.jpg
# -rw------- 1 root root  2938608 Apr  5  2021  IMG_20210324_183959.jpg
# -rw------- 1 root root    54547 Apr  5  2021  IMG-20210324-WA0005.jpg
# -rw------- 1 root root    59465 Apr  5  2021  IMG-20210325-WA0005.jpg
# -rw------- 1 root root    52967 Apr  5  2021  IMG-20210325-WA0006.jpg
# -rw------- 1 root root    60433 Apr  5  2021  IMG-20210325-WA0007.jpg
# -rw------- 1 root root    69044 Apr  5  2021  IMG-20210325-WA0008.jpg
# -rw------- 1 root root    60195 Apr  5  2021  IMG-20210325-WA0009.jpg
# -rw------- 1 root root  2642235 Apr  5  2021  IMG_20210327_111248.jpg
# -rw------- 1 root root  3858291 Apr  5  2021  IMG_20210327_112708.jpg
# -rw------- 1 root root   264901 Apr  5  2021  IMG_20210327_112722.jpg
# -rw------- 1 root root  3633462 Apr  5  2021  IMG_20210328_202325.jpg
# -rw------- 1 root root  3765397 Nov 26  2021  IMG_20210528_182324.jpg
# -rw------- 1 root root  3240801 Nov 26  2021  IMG_20210603_110956.jpg
# -rw------- 1 root root  3107741 Nov 26  2021  IMG_20210603_111011.jpg
# -rw------- 1 root root  3204881 Nov 26  2021  IMG_20210606_203915.jpg
# -rw------- 1 root root  1197174 Nov 26  2021  IMG_20210608_172247.jpg
# -rw------- 1 root root    94736 Nov 26  2021  IMG_20210608_172324.jpg
# -rw------- 1 root root   417424 Nov 26  2021  IMG_20210609_093126.jpg
# -rw------- 1 root root   545444 Nov 26  2021  IMG_20210609_093129.jpg
# -rw------- 1 root root   426265 Nov 26  2021  IMG_20210609_093315.jpg
# -rw------- 1 root root   439621 Nov 26  2021  IMG_20210609_093346.jpg
# -rw------- 1 root root  1473590 Nov 26  2021  IMG_20210609_113059.jpg
# -rw------- 1 root root  4160641 Nov 26  2021  IMG_20210809_093716.jpg
# -rw------- 1 root root    87716 Nov 26  2021  IMG_20210809_094119.jpg
# -rw------- 1 root root  3556881 Nov 26  2021  IMG_20210919_141127.jpg
# -rw------- 1 root root  3516115 Nov 26  2021  IMG_20210919_141129.jpg
# -rw------- 1 root root  4168905 Nov 26  2021  IMG_20210928_175412.jpg
# -rw------- 1 root root  3648604 Nov 26  2021  IMG_20211006_215832.jpg
# -rw------- 1 root root  4102275 Nov 26  2021  IMG_20211011_162506.jpg
# -rw------- 1 root root  4178358 Nov 26  2021  IMG_20211015_193428.jpg
# -rw------- 1 root root  5114014 Nov 26  2021  IMG_20211023_082552.jpg
# -rw------- 1 root root  4271198 Nov 26  2021  IMG_20211101_194456.jpg
# -rw------- 1 root root  4208822 Nov 26  2021  IMG_20211106_165616.jpg
# -rw------- 1 root root  4226903 Nov 26  2021  IMG_20211122_100459.jpg
# -rw------- 1 root root  1940130 Mar 10  2022  IMG_20220203095714149.jpeg
# -rw------- 1 root root  2089278 Mar 10  2022  IMG_20220203095736382.jpeg
# -rw------- 1 root root  2616166 Mar 10  2022  IMG_20220203095751373.jpeg
# -rw------- 1 root root      172 Jan 18 07:35  india_housing_prices.gsheet
# drwx------ 2 root root     4096 Jul 11  2021  Internship
# drwx------ 2 root root     4096 Aug 23  2020  Invoice
# -rw------- 1 root root   524672 Aug 18  2017  iVoomi_iV_Smart_4G_20170806_123358.jpg
# -rw------- 1 root root   710808 Aug 18  2017  iVoomi_iV_Smart_4G_20170806_150513.jpg
# -rw------- 1 root root    98829 Jan 19  2021  iVoomi_iV_Smart_4G_20170806_154407.jpg
# -rw------- 1 root root  1545203 May  4  2018  JAVA.pdf
# -rw------- 1 root root 42044740 Jun  2  2017 'job agreement.zip'
# -rw------- 1 root root   550657 Jul 15  2016  kech201.pdf
# -rw------- 1 root root   727188 Jul 15  2016  kech202.pdf
# -rw------- 1 root root   409527 Jul 15  2016  kech203.pdf
# -rw------- 1 root root   617594 Jul 15  2016  kech204.pdf
# -rw------- 1 root root  1920561 Jul 15  2016  kech206.pdf
# -rw------- 1 root root  4497031 Jul 15  2016  kech207.pdf
# -rw------- 1 root root   345191 Jul 15  2016  kech2an.pdf
# -rw------- 1 root root   275352 Jul 15  2016  kech2ps.pdf
# drwx------ 2 root root     4096 Dec 31  2018 'Krazy bee '
# -rw------- 1 root root  9678645 Feb 11  2020  kupdf.net_make-your-own-neural-network-tariq-rashid-chb-books.pdf
# -rw------- 1 root root       42 Jan 13 04:50  label_encoder.pkl
# -rw------- 1 root root  1292475 Sep 29  2020 'Mahitha L1.pdf'
# drwx------ 2 root root     4096 Jan  9  2021  MasterPython_CodeAndData
# drwx------ 2 root root     4096 Dec 31  2022  Mobile
# -rw------- 1 root root   226541 Sep 12  2016 'MOLE CONCEPT (ADVANCED SOLUTION).pdf'
# drwx------ 2 root root     4096 Aug 23  2020  Mpokket
# -rw------- 1 root root  4075680 Aug  7  2020 "My_Mother's_Cause_of_death_certificate.png.jpg"
# -rw------- 1 root root      172 Jan  4  2021  naca.gsheet
# -rw------- 1 root root     2908 Jan  4  2021  naca.txt
# -rw------- 1 root root 12765219 Dec 15  2018 'New Doc 2018-12-15 22.56.48.pdf'
# -rw------- 1 root root      172 Jul  9  2019  newfile.py.gdoc
# drwx------ 2 root root     4096 Sep  3  2020 'New folder'
# drwx------ 2 root root     4096 Sep 30  2016 'new folder 2'
# drwx------ 2 root root     4096 Sep 30  2016 'New folder (2)'
# -rw------- 1 root root   610057 Sep 24  2017 "Newton's ring experiment.pdf"
# -rw------- 1 root root  1164692 Nov 10  2017  Nor1.jpg
# -rw------- 1 root root  1450127 Nov 10  2017  Nor2.jpg
# -rw------- 1 root root  1207683 Nov 10  2017  Nor3.jpg
# -rw------- 1 root root  1154496 Nov 10  2017  Nor4.jpg
# -rw------- 1 root root  1126967 Nov 10  2017  Nor5.jpg
# -rw------- 1 root root  1245795 Nov 10  2017  Nor6.jpg
# -rw------- 1 root root 20069418 Jun 12  2018 'OBJ-1 (1).pdf'
# -rw------- 1 root root 20069418 Jun 12  2018  OBJ-1.pdf
# -rw------- 1 root root   187601 Oct  8  2017  ofstudies-150717070631-lva1-app6892.pptx
# drwx------ 2 root root     4096 Aug 23  2020  Orders
# -rw------- 1 root root    67914 Oct 28  2017 'Photo from Sravan'
# drwx------ 2 root root     4096 Aug 17  2018  Photography
# -rw------- 1 root root  3899291 May 16  2022  Photo.jpg
# -rw------- 1 root root   136571 Oct  6  2017  physics
# -rw------- 1 root root   318247 Feb  6  2018 'Physics Assignment 1.pdf'
# -rw------- 1 root root      172 Jan 24 13:52 'Plant_disease_project (1).gdoc'
# -rw------- 1 root root      161 Feb  6  2024  Portfolio.gsite
# -rw------- 1 root root  3432125 May 16  2022 'Portrait photo.jpg'
# -rw------- 1 root root 54874395 Oct 13  2020 'Principles of Instrumental Analysis sixth edition ( PDFDrive ).pdf'
# -rw------- 1 root root   154322 Aug  5  2021  psvss2k@gmail.com_MEI2021AANL_Signed.pdf
# -rw------- 1 root root   400657 Jul 26  2023 'PSVS Sai Sravan.pdf'
# -rw------- 1 root root   374550 Jul  6  2023 'PSVS Sai Sravan Resume.pdf'
# -rw------- 1 root root    20418 Feb 24  2016 'PVRSS photo 1.jpg'
# -rw------- 1 root root  5081783 Jun 12  2018 'quantum mechanics.pdf'
# -rw------- 1 root root     6390 Aug 14  2020 'Remainder 6.docx'
# -rw------- 1 root root    51838 Oct 19  2020  Repayment_receipt_CR33FE5F67ID11260612.pdf
# -rw------- 1 root root   303432 Jun 19  2021 'Resume (1).pdf'
# -rw------- 1 root root   303716 Apr 29  2021 'Resume (2).pdf'
# -rw------- 1 root root   400657 Jul 26  2023  Resume.pdf
# -rw------- 1 root root   686563 Jun  1  2022  SaiSravanPSVS.pptx
# -rw------- 1 root root 31577168 Mar 11  2022 'Sai Sravan PSVS.zip'
# -rw------- 1 root root    23243 Jan 13 04:50  sample_images.png
# -rw------- 1 root root   554562 Jul 23  2020  Screenshot_2020-07-23-20-48-56-60.png
# -rw------- 1 root root   482056 Jul 23  2020  Screenshot_2020-07-23-20-50-09-88.png
# -rw------- 1 root root   536574 Jul 23  2020  Screenshot_2020-07-23-20-51-16-65.png
# -rw------- 1 root root   398021 Feb 25  2023  Screenshot_2023-02-25-17-31-39-060_in.amazon.mShop.android.shopping.jpg
# -rw------- 1 root root   291009 Jul  3  2023  Screenshot_2023-07-03-22-02-44-721_in.amazon.mShop.android.shopping.jpg
# drwx------ 2 root root     4096 Sep 30  2018  Sem3
# drwx------ 2 root root     4096 Aug 22  2020  sem5
# drwx------ 2 root root     4096 Aug 23  2020  Sidharth
# -rw------- 1 root root  1217559 Sep 20  2022  Signature.jpg
# -rw------- 1 root root  3347568 Jan 15  2022 'Spur Gear Modelling and Structural Analysis by PSVS Sai Sravan.pdf'
# drwx------ 2 root root     4096 Oct  6  2017 'sravan info from hill'
# -rw------- 1 root root    49271 Jul 29  2019 'sravan photo 2.jpg'
# -rw------- 1 root root    22022 Jul 29  2019 'sravan photo.jpg'
# -rw------- 1 root root    14815 Jul 29  2019 'sravan signature1.jpg'
# -rw------- 1 root root     1731 Jul 29  2019 'sravan signature.jpg'
# -rw------- 1 root root  2398428 May  5  2017 '_. SRM 2017 Online Examination Slot Selection .pdf'
# -rw------- 1 root root 18603102 May 18  2021  sr.pdf
# -rw------- 1 root root    20443 Oct  8  2017 'the necklace.docx'
# drwx------ 2 root root     4096 May  9  2021  Tool_Test
# -rw------- 1 root root      172 Aug 11  2020  trans.gdoc
# -rw------- 1 root root      172 Aug 21  2020 'Untitled document.gdoc'
# -rw------- 1 root root      172 Apr  3  2025 'Untitled form.gform'
# -rw------- 1 root root   410523 Sep 29  2020 'Untitled Jam (1).pdf'
# -rw------- 1 root root   226497 Sep 26  2020 'Untitled Jam (2).pdf'
# -rw------- 1 root root   588956 Dec 11  2020 'Untitled Jam.pdf'
# -rw------- 1 root root      172 Jan  4  2021 'Untitled spreadsheet (1).gsheet'
# -rw------- 1 root root      172 Aug 20  2020 'Untitled spreadsheet (2).gsheet'
# -rw------- 1 root root      172 Jul 27  2021 'Untitled spreadsheet.gsheet'
# -rw------- 1 root root   927744 Apr 13  2019 'Use Of Pitot st-WPS Office (1).doc'
# -rw------- 1 root root      172 Apr 13  2019 'Use Of Pitot st-WPS Office (1).gdoc'
# -rw------- 1 root root 33715712 Mar  2  2017  ushainterinppt.ppt
# -rw------- 1 root root      161 Feb  6  2024 'US Infratech.gsite'
# -rw------- 1 root root 36067717 Sep 22  2017  VID_20160730_091317.3gp
# -rw------- 1 root root 13962324 Nov 26  2017  VID-20171029-WA0005.mp4
# -rw------- 1 root root 69666505 Nov 26  2021  VID_20211015_173822.mp4
# -rw------- 1 root root      172 Aug  7 07:23 'What is my prompting skill you have noticed so fa....gsheet'
# -rw------- 1 root root      172 Sep 23  2020 'WhatsApp Chat with B.tech div -- B 2017.gdoc'
# -rw------- 1 root root   903705 Jun  1  2018 'WhatsApp Chat with B.tech div -- B 2017.txt'
#
# ============================================================
# Searching for cleaned dataset...
# Found: /content/drive/MyDrive/india_housing_prices.gsheet
# Found: /content/drive/MyDrive/assignment-3/data/india_housing_prices_cleaned.csv

# %%
# Load cleaned dataset from correct path
print("\n" + "="*60)
print("LOADING CLEANED DATASET")
print("="*60)

df = pd.read_csv('/content/drive/MyDrive/assignment-3/data/india_housing_prices_cleaned.csv')

print(f"\n✅ Dataset loaded successfully!")
print(f"Shape: {df.shape}")
print(f"\nColumns: {list(df.columns)}")
print(f"\nData types:")
print(df.dtypes)
print(f"\nFirst few rows:")
df.head()
# Out:
# ============================================================
# LOADING CLEANED DATASET
# ============================================================
#
# ✅ Dataset loaded successfully!
# Shape: (247466, 23)
#
# Columns: ['ID', 'State', 'City', 'Locality', 'Property_Type', 'BHK', 'Size_in_SqFt', 'Price_in_Lakhs', 'Price_per_SqFt', 'Year_Built', 'Furnished_Status', 'Floor_No', 'Total_Floors', 'Age_of_Property', 'Nearby_Schools', 'Nearby_Hospitals', 'Public_Transport_Accessibility', 'Parking_Space', 'Security', 'Amenities', 'Facing', 'Owner_Type', 'Availability_Status']
#
# Data types:
# ID                                  int64
# State                              object
# City                               object
# Locality                           object
# Property_Type                      object
# BHK                                 int64
# Size_in_SqFt                        int64
# Price_in_Lakhs                    float64
# Price_per_SqFt                    float64
# Year_Built                          int64
# Furnished_Status                   object
# Floor_No                            int64
# Total_Floors                        int64
# Age_of_Property                     int64
# Nearby_Schools                      int64
# Nearby_Hospitals                    int64
# Public_Transport_Accessibility     object
# Parking_Space                      object
# Security                           object
# Amenities                          object
# Facing                             object
# Owner_Type                         object
# Availability_Status                object
# dtype: object
#
# First few rows:
#    ID        State      City      Locality      Property_Type  BHK  \
# 0   1   Tamil Nadu   Chennai   Locality_84          Apartment    1
# 1   2  Maharashtra      Pune  Locality_490  Independent House    3
# 2   3       Punjab  Ludhiana  Locality_167          Apartment    2
# 3   4    Rajasthan   Jodhpur  Locality_393  Independent House    2
# 4   5    Rajasthan    Jaipur  Locality_466              Villa    4
#
#    Size_in_SqFt  Price_in_Lakhs  Price_per_SqFt  Year_Built  ...  \
# 0          4740          489.76            0.10        1990  ...
# 1          2364          195.52            0.08        2008  ...
# 2          3642          183.79            0.05        1997  ...
# 3          2741          300.29            0.11        1991  ...
# 4          4823          182.90            0.04        2002  ...
#
#   Age_of_Property  Nearby_Schools  Nearby_Hospitals  \
# 0              35              10                 3
# 1              17               8                 1
# 2              28               9                 8
# 3              34               5                 7
# 4              23               4                 9
#
#    Public_Transport_Accessibility  Parking_Space  Security  \
# 0                            High             No        No
# 1                             Low             No       Yes
# 2                             Low            Yes        No
# 3                            High            Yes       Yes
# 4                             Low             No       Yes
#
#                                   Amenities Facing Owner_Type  \
# 0  Playground, Gym, Garden, Pool, Clubhouse   West      Owner
# 1  Playground, Clubhouse, Pool, Gym, Garden  North    Builder
# 2          Clubhouse, Pool, Playground, Gym  South     Broker
# 3  Playground, Clubhouse, Gym, Pool, Garden  North    Builder
# 4  Playground, Garden, Gym, Pool, Clubhouse   East    Builder
#
#   Availability_Status
# 0       Ready_to_Move
# 1  Under_Construction
# 2       Ready_to_Move
# 3       Ready_to_Move
# 4       Ready_to_Move
#
# [5 rows x 23 columns]
